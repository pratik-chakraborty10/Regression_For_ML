# %% [markdown]
# <a href="https://colab.research.google.com/github/pratik-chakraborty10/Regression_For_ML/blob/main/Simple_Linear_Regression_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing Data Set

# %%
data_set=pd.read_csv(" Salary_data.csv")
X=data_set.iloc[:,:-1].values  #getting all the rows except the last column
y=data_set.iloc[:,-1].values #getting only the last col

# %% [markdown]
# ## Splitting into test and training set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %% [markdown]
# ## Training on Training Set using Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression() #instance of LinearRegression class
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction on Test Set

# %%
y_pred=regressor.predict(X_test)

# %% [markdown]
# ## Visualizing the Training Set

# %%
plt.scatter(X_train,y_train,color="red")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("CTC V/S  YEARS OF EXPERIENCE")
plt.xlabel("Experience in years")
plt.ylabel("CTC")
plt.show()

# %% [markdown]
# ## Visualizing the Test Set

# %%
plt.scatter(X_test,y_test,color="cyan")
plt.plot(X_train,regressor.predict(X_train),color="blue")
plt.title("CTC V/S  YEARS OF EXPERIENCE")
plt.xlabel("Experience in years")
plt.ylabel("CTC")
plt.show()
